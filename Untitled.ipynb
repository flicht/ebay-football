# %%
import pandas as pd

# %%
df = pd.read_csv('data/2020-6-5-17.csv', header=None)

# %%
df.sort_values(by=3, ascending=False)
# Out:
#                      0             1                      2    3
# 218          liverpool  402285219237    Virgil Van Dijk (4)  336
# 229          liverpool  402285219258  Jordan Henderson (14)  279
# 235          liverpool  402285219263    Roberto Firmino (9)  244
# 400  tottenham-hotspur  402285221174        Harry Kane (10)  205
# 213          liverpool  402285219214     Alisson Becker (1)  186
# ..                 ...           ...                    ...  ...
# 341   sheffield-united  402285220255    Kieron Freeman (18)    0
# 410            watford  402285221173       Adam Masina (11)    0
# 182            everton  402285222556    Beni Baningime (34)    0
# 183            everton  402285222555   Dennis Adeniran (35)    0
# 327       norwich-city  402285220294       Josip Drmić (20)    0
#
# [472 rows x 4 columns]

# %%
df.sort_values(by=3).head(50)
# Out:
#                            0             1  \
# 341         sheffield-united  402285220255
# 327             norwich-city  402285220294
# 183                  everton  402285222555
# 182                  everton  402285222556
# 410                  watford  402285221173
# 419                  watford  402285221253
# 406                  watford  402285221297
# 144           crystal-palace  402285217924
# 364              southampton  402285221171
# 416                  watford  402285221257
# 365              southampton  402285221262
# 316             norwich-city  402285220232
# 414                  watford  402285221251
# 312             norwich-city  402285220260
# 411                  watford  402285221247
# 412                  watford  402285221255
# 420                  watford  402285221198
# 107                  burnley  402285217944
# 409                  watford  402285221220
# 96                   burnley  402285217891
# 238          manchester-city  402285219280
# ...

# %%
df.shape
# Out:
# (472, 4)

# %%
print(df[df[3]==0])
# Out:
#                     0             1                     2  3
# 182           everton  402285222556   Beni Baningime (34)  0
# 183           everton  402285222555  Dennis Adeniran (35)  0
# 327      norwich-city  402285220294      Josip Drmić (20)  0
# 341  sheffield-united  402285220255   Kieron Freeman (18)  0
# 410           watford  402285221173      Adam Masina (11)  0

# %%
df_recent = pd.read_csv('data/2020-6-5-22.csv', header=None)

# %%
df_recent.sort_values(by=3, ascending=False)
# Out:
#                      0             1                            2    3
# 219          liverpool  402285219237          Virgil Van Dijk (4)  386
# 231          liverpool  402285219258        Jordan Henderson (14)  320
# 237          liverpool  402285219263          Roberto Firmino (9)  278
# 401  tottenham-hotspur  402285221174              Harry Kane (10)  251
# 225          liverpool  402285219213  Trent Alexander-Arnold (66)  248
# ..                 ...           ...                          ...  ...
# 411            watford  402285221173             Adam Masina (11)    1
# 97             burnley  402285217891  Bailey Peacock-Farrell (15)    1
# 10     afc-bournemouth  402285222089            Jack Simpson (25)    1
# 184            everton  402285222555         Dennis Adeniran (35)    0
# 183            everton  402285222556          Beni Baningime (34)    0
#
# [473 rows x 4 columns]
